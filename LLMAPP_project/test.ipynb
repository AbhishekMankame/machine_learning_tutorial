# %%
# import libraries

# !pip install openai
# !pip install pinecone
# !pip install langchain
import openai
import langchain
import pinecone
# Out:
# Requirement already satisfied: openai in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (2.38.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/codespace/.local/lib/python3.12/site-packages (from openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/codespace/.local/lib/python3.12/site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from openai) (0.15.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from openai) (2.13.4)
# Requirement already satisfied: sniffio in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from openai) (4.67.3)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /home/codespace/.local/lib/python3.12/site-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /home/codespace/.local/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: pinecone in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (9.0.1)
# Requirement already satisfied: httpx<1.0,>=0.27 in /home/codespace/.local/lib/python3.12/site-packages (from httpx[http2]<1.0,>=0.27->pinecone) (0.28.1)
# Requirement already satisfied: msgspec in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from pinecone) (0.21.1)
# Requirement already satisfied: orjson in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from pinecone) (3.11.9)
# Requirement already satisfied: anyio in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1.0,>=0.27->httpx[http2]<1.0,>=0.27->pinecone) (4.12.1)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1.0,>=0.27->httpx[http2]<1.0,>=0.27->pinecone) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1.0,>=0.27->httpx[http2]<1.0,>=0.27->pinecone) (1.0.9)
# Requirement already satisfied: idna in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1.0,>=0.27->httpx[http2]<1.0,>=0.27->pinecone) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0,>=0.27->httpx[http2]<1.0,>=0.27->pinecone) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from httpx[http2]<1.0,>=0.27->pinecone) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]<1.0,>=0.27->pinecone) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from h2<5,>=3->httpx[http2]<1.0,>=0.27->pinecone) (4.1.0)
# Requirement already satisfied: typing_extensions>=4.5 in /home/codespace/.local/lib/python3.12/site-packages (from anyio->httpx<1.0,>=0.27->httpx[http2]<1.0,>=0.27->pinecone) (4.15.0)
# Requirement already satisfied: langchain in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (1.2.18)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.3 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain) (1.3.3)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.10 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain) (1.1.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (0.8.3)
# Requirement already satisfied: packaging>=23.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/codespace/.local/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /home/codespace/.local/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.3->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (4.0.3)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.12 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (1.0.13)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (0.3.14)
# Requirement already satisfied: xxhash>=3.5.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.10->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /home/codespace/.local/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (0.25.0)
# Requirement already satisfied: anyio in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (4.12.1)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (1.0.9)
# Requirement already satisfied: idna in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (2.6.3)

# %%
# !pip uninstall -y langchain
# !pip install -U langchain langchain-community langchain-openai
# !pip install langchain-text-splitters
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Pinecone
from langchain.llms import OpenAI
# Out:
# Found existing installation: langchain 1.3.2
# Uninstalling langchain-1.3.2:
#   Successfully uninstalled langchain-1.3.2
# Collecting langchain
#   Using cached langchain-1.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: langchain-community in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (0.4.2)
# Requirement already satisfied: langchain-openai in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (1.2.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain) (1.4.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.2 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain) (1.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.8.3)
# Requirement already satisfied: packaging>=23.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/codespace/.local/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /home/codespace/.local/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (0.3.14)
# Requirement already satisfied: xxhash>=3.5.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.2->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in /home/codespace/.local/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (4.12.1)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (1.0.9)
# Requirement already satisfied: idna in /home/codespace/.local/lib/python3.12/site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-community) (3.13.5)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-community) (1.0.7)
# Requirement already satisfied: numpy>=1.26.2 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-community) (2.4.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-community) (2.14.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (2.6.3)
# Requirement already satisfied: greenlet>=1 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.0)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-openai) (2.38.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.15.0)
# Requirement already satisfied: sniffio in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.3)
# Requirement already satisfied: regex in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.4.4)
# Using cached langchain-1.3.2-py3-none-any.whl (121 kB)
# Installing collected packages: langchain
# Successfully installed langchain-1.3.2
# Requirement already satisfied: langchain-text-splitters in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (1.1.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.31 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-text-splitters) (1.4.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.8.3)
# Requirement already satisfied: packaging>=23.2.0 in /home/codespace/.local/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/codespace/.local/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/codespace/.local/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in /home/codespace/.local/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/codespace/.local/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/codespace/.local/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.32.5)
# Requirement already satisfied: xxhash>=3.0.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.25.0)
# Requirement already satisfied: anyio in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (4.12.1)
# Requirement already satisfied: certifi in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (1.0.9)
# Requirement already satisfied: idna in /home/codespace/.local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/codespace/.local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /workspaces/machine_learning_tutorial/venv/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (3.4.5)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain-text-splitters) (2.6.3)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 6
#       4 from langchain_community.document_loaders import TextLoader
#       5 from langchain_text_splitters import RecursiveCharacterTextSplitter
# ----> 6 from langchain.embeddings.openai import OpenAIEmbeddings
#       7 from langchain.vectorstores import Pinecone
#       8 from langchain.llms import OpenAI
#
# ModuleNotFoundError: No module named 'langchain.embeddings.openai'

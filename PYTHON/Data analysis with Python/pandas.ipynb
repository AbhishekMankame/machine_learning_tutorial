# %% [markdown]
# ## Pandas-DataFrame And Series
# Pandas is a powerful data manipulation library in Python, widely used for data analysis and data cleaning. It provides two primary data structures: Series and DataFrame.
# A Series is a one-dimensional array-like object, while a DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data strucutre with labeled axes (rows and columns).

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
## Series
## Pandas series is one-dimensional array-like object that can hold any data type. It is similar to a column in a table.

# %%
data = [1,2,3,4,5]
series = pd.Series(data)
print(series)
print(type(series))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.Series'>

# %%
## Create a series from dictonary
data = {'a':1,'b':2,'c':3}
series_dict = pd.Series(data)
print(data)
print(series_dict)
# Out:
# {'a': 1, 'b': 2, 'c': 3}
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = [10,20,30]
index = ['a','b','c']
pd.Series(data,index=index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
## DataFrame
## create a DataFrame from a dictionary of list

data={
    'Name':['Krish','John','Jack'],
    'Age':[25,30,45],
    'City':['Bangalore','New York','Florida']
}

df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Name  Age       City
# 0  Krish   25  Bangalore
# 1   John   30   New York
# 2   Jack   45    Florida
# <class 'pandas.DataFrame'>

# %%
import numpy as np
np.array(df)
# Out:
# array([['Krish', 25, 'Bangalore'],
#        ['John', 30, 'New York'],
#        ['Jack', 45, 'Florida']], dtype=object)

# %%
## Create a Data frame from a List of Dictionaries
data=[
    {'Name':'Krish','Age':32,'City':'Bangalore'},
    {'Name':'John','Age':32,'City':'Bangalore'},
    {'Name':'Alice','Age':32,'City':'Bangalore'},
    {'Name':'Bob','Age':32,'City':'Bangalore'}
    
]
df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#     Name  Age       City
# 0  Krish   32  Bangalore
# 1   John   32  Bangalore
# 2  Alice   32  Bangalore
# 3    Bob   32  Bangalore
# <class 'pandas.DataFrame'>

# %%
df
# Out:
#     Name  Age       City
# 0  Krish   32  Bangalore
# 1   John   32  Bangalore
# 2  Alice   32  Bangalore
# 3    Bob   32  Bangalore

# %%
df['Name']
# Out:
# 0    Krish
# 1     John
# 2    Alice
# 3      Bob
# Name: Name, dtype: str

# %%
type(df['Name'])
# Out:
# pandas.Series

# %%
df.loc(0)

# %%
df.loc[0]
# Out:
# Name        Krish
# Age            32
# City    Bangalore
# Name: 0, dtype: object

# %%
## Accessing a specified element
df['Name']
# Out:
# 0    Krish
# 1     John
# 2    Alice
# 3      Bob
# Name: Name, dtype: str

# %%
df.at[1,'Age']
# Out:
# np.int64(32)

# %%
df.at[2,'Age']
# Out:
# np.int64(32)

# %%
print(df.at[2,'Age'])
# Out:
# 32
